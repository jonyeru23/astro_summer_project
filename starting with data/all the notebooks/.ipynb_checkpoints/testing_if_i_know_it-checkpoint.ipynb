# %%
import openpyxl

path = "the data.xlsx"
wb = openpyxl.load_workbook(path)

ws_main = wb['raw data']
ws1 = wb['important']

for row in range(2, 113):
    if type(ws_main[f'A{row}'].value) is int:
        elements = [cell.value for cell in ws_main[row]]
        print(elements)
        ws1.append(elements)
wb.save(path)
# Out:
# [1, 0.69085648, 20, '> 19.4', '1.77 ± 0.34 ', None]
# [2, 0.69115741, 20, '> 19.4', '1.70 ± 0.26 ', None]
# [3, 0.69143519, 20, '> 19.4', '1.74 ± 0.45 ', None]
# [4, 0.69172454, 20, '> 19.4', '2.20 ± 0.28 ', None]
# [5, 0.69200231, 20, '> 19.4', '2.02 ± 0.33 ', None]
# [6, 0.69229167, 20, '> 19.4', '1.69 ± 0.48 ', None]
# [7, 0.69256944, 20, '> 19.4', '2.13 ± 0.29 ', None]
# [8, 0.6928588, 20, '> 19.4', '2.31 ± 0.31 ', None]
# [9, 0.69314815, 20, '> 19.4', '1.96 ± 0.27 ', None]
# [10, 0.69351852, 20, '> 19.4', '1.96 ± 0.43 ', None]
# [11, 0.69387731, 20, '> 19.4', '1.74 ± 0.27 ', None]
# [12, 0.69416667, 20, '> 19.4', '2.68 ± 0.48 ', None]
# [13, 0.69445602, 20, '> 19.4', '2.26 ± 0.30 ', None]
# [14, 0.69474537, 20, '> 19.4', '1.84 ± 0.34 ', None]
# [15, 0.6950463, 20, '> 19.4', '2.16 ± 0.28 ', None]
# [16, 0.69534722, 20, '> 19.4', '1.81 ± 0.44 ', None]
# [17, 0.69563657, 20, '> 19.4', '1.89 ± 0.46 ', None]
# [18, 0.69592593, 20, '> 19.4', '1.92 ± 0.32 ', None]
# ...
